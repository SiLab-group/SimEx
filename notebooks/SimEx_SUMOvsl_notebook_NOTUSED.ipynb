# %% [markdown]
# # SimEx sumovsl

# %%
from modifier import Modifier
from global_settings import sumovsls

def modifier_sumo(interval_list, modifier_list):
        # Get interval [1.25, 2.75]
        # Get the values from the modifier array for the interval ID,[value,...]
        # Resample traffic volume with different granularity
        interval_ids = [[int(num) for num in interval] for interval in interval_list]
        mlist = []
        for interval in interval_ids:
            ids = []
            volume = []
            print(f"Print interval {interval}")
            # Get traffic volume for each id
            # We assume, constant volume per interval
            start = modifier_list[interval[0]-1][1][0]
            end = modifier_list[interval[1]-1][1][0]
            # Create step for traffic volume
            step = 25
            for value in range(start, end, step):
                volume.append(value)

            ids = Modifier.rescale(volume,interval[0],interval[1])
            print(f"volume {volume}")
            for i in range(0,len(ids)-1):
                mlist.append([ids[i],[volume[i]]*90])
            print(f"MOD list {mlist}")
        return mlist

# %%
sumovsls = {"model_path": "/home/amy/tmp/repos/sumovsl/SPSC_MD/model_MD/",
          "sumo_path": "/usr/share/sumo/bin/sumo-gui",
            "step_modifier": "25"}

# %%
# IMPORT LIBRARIES
import numpy as np

from components_configuration import components
from global_settings import simexSettings,mds

from validator_controller import ValidatorController
from modifier_controller import ModifierController
from simulator_controller import SimulatorController
from logger_utils import Logger

validator_controller_vsl = ValidatorController()
logger = Logger()
logger_main_arguments = {}
is_main_func = True

# SUMO vsl
from controller_modifier_scenarios import Controller

modlist = Controller.get_list_of_modifiers(10)
mod_x,sim_y_list = SimulatorController.simulator(modlist,selected_simulator=components['sumo_simulator_vsl'])
assert len(mod_x) == len(sim_y_list)

while is_main_func:
    # SUMO vsl generate modifiers [[1,[2900,...2900],[2,[3000,...3000]....]
    # modlist = Controller.get_list_of_modifiers(10)
    # print(f"Mod list: {modlist}")
    # mod_x_list = modlist
    
     # Calls Validator controller
    intervals_list =  validator_controller_vsl.validate(mod_x_list=np.array(mod_x),sim_y_list=np.array(sim_y_list), selected_validator=components['validator'],global_interval=[1, 10])
    print("MAIN interval list from VAL:", intervals_list)
    
    # Calls Modifier Controller
    if intervals_list:
        # Calls Modifier Controller
        mod_x_list = modifier_sumo(intervals_list,modlist)
        print("MAIN mod outcome", mod_x_list)
    
        mod_x,sim_y_list = SimulatorController.simulator(mod_x_list,selected_simulator=components['sumo_simulator_vsl'])
        assert len(mod_x) == len(sim_y_list)
        intervals_list_vsl =  validator_controller_vsl.validate(mod_x_list=np.array(mod_x),sim_y_list=np.array(sim_y_list), selected_validator=components['validator'],global_interval=[1, 10])

    print("MAIN modx", mod_x)
    # breaks loop if iterations end by granularity reached
    if not mod_x_list: # FALSE IF ['modifier_data_point'] < mdv['modifier_incremental_unit']:
        logger_main_arguments['log_contex'] = 'overall MAIN stats'
        logger_main_arguments['main_status'] = 'no generated points'
        #logger_main_arguments['remaining_unfit_intervals'] = checked_intervals
        logger.log_main(logger_main_arguments)
        break
    

    # Calls Validator controller
    intervals_list =  validator_controller_vsl.validate(mod_x_list=np.array(mod_x),sim_y_list=np.array(sim_y_list), selected_validator=components['validator'],global_interval=[1, 10])
    print("MAIN interval list from VAL:", intervals_list)
    # print(f"Fitted curve {validator_controller_vsl.fitted_curve} and Pred values {validator_controller_vsl.predicted_values}")
    
    # Updates interval_list to new range output from validator controller
    # No more unfit intervals -> write MAIN log
    if not intervals_list:
        is_main_func = False
        logger_main_arguments['log_contex'] = 'overall MAIN stats'
        logger_main_arguments['main_status'] = 'no unfit intervals'
        logger.log_main(logger_main_arguments)

# MAIN cycle completed/interrupted -> write OVERALL statistics          
logger_main_arguments['log_contex'] = 'Overall Stats'                          
logger_main_arguments['main_status'] = 'end cycle'
logger.log_main(logger_main_arguments)
# Out:
# Simulator...
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Validator...
#        *** USING local_exploration_validator_A
#        *** USING get_fit_intervals:   [[1, 3.25]]
# MAIN interval list from VAL: [[3.25, 4.75], [5.25, 6.75], [7.25, 10]]
# Print interval [3, 4]
# volume [3100, 3125, 3150, 3175]
# MOD list [[3.0, [3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100]], [3.3333333333333335, [3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125]], [3.6666666666666665, [3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150]]]
# Print interval [5, 6]
# volume [3300, 3325, 3350, 3375]
# MOD list [[3.0, [3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100]], [3.3333333333333335, [3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125]], [3.6666666666666665, [3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150]], [5.0, [3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300]], [5.333333333333333, [3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325]], [5.666666666666667, [3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350]]]
# Print interval [7, 10]
# volume [3500, 3525, 3550, 3575, 3600, 3625, 3650, 3675, 3700, 3725, 3750, 3775]
# MOD list [[3.0, [3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100]], [3.3333333333333335, [3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125]], [3.6666666666666665, [3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150]], [5.0, [3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300]], [5.333333333333333, [3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325]], [5.666666666666667, [3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350]], [7.0, [3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500]], [7.2727272727272725, [3525, 3525, 3525, 3525, 3525, 3525, 3525, 3525, 3525, 3525, 3525, 3 ...
# MAIN mod outcome [[3.0, [3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100, 3100]], [3.3333333333333335, [3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125, 3125]], [3.6666666666666665, [3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150, 3150]], [5.0, [3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300, 3300]], [5.333333333333333, [3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325, 3325]], [5.666666666666667, [3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350, 3350]], [7.0, [3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500, 3500]], [7.2727272727272725, [3525, 3525, 3525, 3525, 3525, 3525, 3525, 3525, 3525, 3525, ...
# Simulator...
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Validator...
# What are POINTS  [[3.0, 422.25], [3.3333333333333335, 435.15277777777794], [3.6666666666666665, 443.56944444444457], [5.0, 492.68055555555554], [5.333333333333333, 489.6527777777779], [5.666666666666667, 520.4722222222221], [7.0, 577.8333333333333], [7.2727272727272725, 575.9444444444443], [7.545454545454545, 574.8055555555557], [7.818181818181818, 635.1111111111112], [8.09090909090909, 635.0277777777777], [8.363636363636363, 604.8472222222223], [8.636363636363637, 659.9583333333333], [8.90909090909091, 661.4444444444441], [9.181818181818182, 699.5972222222224], [9.454545454545455, 716.6805555555554], [9.727272727272727, 717.1249999999998], [4, 441.27777777777777], [6, 522.5972222222222], [8, 635.0277777777777], [9, 699.5972222222224], [10, 722.0694444444445]]
#        *** USING local_exploration_validator_A
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# equation,
#  y =  -0.000982041425337138x^7  -0.008907740840685468x^6  -0.03479800909092333x^5  -0.04951808026046389x^4 + 0.490934770638177x^3 + 5.845043241648374x^2 + 42.08226993988039x^1 + 248.89384388299447
# unfit_points
#  [(3.3333333333333335, 435.15277777777794), (3.6666666666666665, 443.56944444444457), (4, 441.27777777777777)]
# local_unfit_interval
# , [[3.25, 4.75]]
#        *** USING local_exploration_validator_A
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# equation,
#  y =  -2.475299414975501e-05x^9  -6.773062169971794e-05x^8  -8.1462419280787e-06x^7 + 0.0017813026574182887x^6 + 0.018163971161815347x^5 + 0.132604355658804x^4 + 0.813429201961866x^3 + 4.294890650397545x^2 + 18.580416654455757x^1 + 50.08622219300098
# unfit_points
#  [(5.333333333333333, 489.6527777777779), (5.666666666666667, 520.4722222222221), (6, 522.5972222222222)]
# local_unfit_interval
# , [[5.25, 6.75]]
#        *** USING local_exploration_validator_A
#        *** USING get_fit_intervals:   [[7.25, 7.340909090909091]]
# equation,
#  y =  -5.286199287471967x^2 + 148.8244093463881x^1  -229.55860645946274
# unfit_points
#  [(7.2727272727272725, 575.9444444444443), (7.545454545454545, 574.8055555555557), (7.818181818181818, 635.1111111111112), (8, 635.0277777777777), (8.09090909090909, 635.0277777777777), (8.363636363636363, 604.8472222222223), (8.636363636363637, 659.9583333333333), (8.90909090909091, 661.4444444444441), (9, 699.5972222222224), (9.181818181818182, 699.5972222222224), (9.454545454545455, 716.6805555555554), (9.727272727272727, 717.1249999999998), (10, 722.0694444444445)]
# local_unfit_interval
# , [[7.25, 7.340909090909091], [8.568181818181818, 8.704545454545455], [9.659090909090908, 9.795454545454545]]
# DIFFERENCES
# each_interval  [7.25, 10]
# new_unfit_interval   [[7.340909090909091, 8.568181818181818], [8.704545454545455, 9.659090909090908], [9.795454545454545, 10]]
# MAIN modx [3.0, 3.3333333333333335, 3.6666666666666665, 5.0, 5.333333333333333, 5.666666666666667, 7.0, 7.2727272727272725, 7.545454545454545, 7.818181818181818, 8.09090909090909, 8.363636363636363, 8.636363636363637, 8.90909090909091, 9.181818181818182, 9.454545454545455, 9.727272727272727]
# Validator...
# What are POINTS  [[3.0, 422.25], [3.3333333333333335, 435.15277777777794], [3.6666666666666665, 443.56944444444457], [5.0, 492.68055555555554], [5.333333333333333, 489.6527777777779], [5.666666666666667, 520.4722222222221], [7.0, 577.8333333333333], [7.2727272727272725, 575.9444444444443], [7.545454545454545, 574.8055555555557], [7.818181818181818, 635.1111111111112], [8.09090909090909, 635.0277777777777], [8.363636363636363, 604.8472222222223], [8.636363636363637, 659.9583333333333], [8.90909090909091, 661.4444444444441], [9.181818181818182, 699.5972222222224], [9.454545454545455, 716.6805555555554], [9.727272727272727, 717.1249999999998], [7.545454545454545, 574.8055555555557], [7.818181818181818, 635.1111111111112], [8, 635.0277777777777], [8.09090909090909, 635.0277777777777], [8.363636363636363, 604.8472222222223], [8.90909090909091, 661.4444444444441], [9, 699.5972222222224], [9.181818181818182, 699.5972222222224], [9.454545454545455, 716.6805555555554], [10, 722.0694444444445]]
#        *** USING local_exploration_validator_A
#        *** USING get_fit_intervals:   [[7.340909090909091, 7.613636363636363]]
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# equation,
#  y =  -293.86875505466355x^2 + 4707.894608802407x^1  -18215.53117581124
# unfit_points
#  [(7.545454545454545, 574.8055555555557), (7.545454545454545, 574.8055555555557), (7.818181818181818, 635.1111111111112), (7.818181818181818, 635.1111111111112), (8, 635.0277777777777), (8.09090909090909, 635.0277777777777), (8.09090909090909, 635.0277777777777), (8.363636363636363, 604.8472222222223), (8.363636363636363, 604.8472222222223)]
# local_unfit_interval
# , [[7.340909090909091, 7.613636363636363], [7.954545454545455, 8.568181818181818]]
#        *** USING local_exploration_validator_A
#        *** USING get_fit_intervals:   [[8.704545454545455, 8.931818181818183]]
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# equation,
#  y =  -180.99109937415196x^2 + 3414.187043560094x^1  -15385.371674502943
# unfit_points
#  [(8.90909090909091, 661.4444444444441), (8.90909090909091, 661.4444444444441), (9, 699.5972222222224), (9.181818181818182, 699.5972222222224), (9.181818181818182, 699.5972222222224), (9.454545454545455, 716.6805555555554), (9.454545454545455, 716.6805555555554)]
# local_unfit_interval
# , [[8.704545454545455, 8.931818181818183], [9.136363636363637, 9.659090909090908]]
# This is UNFIT POINTS  [(10, 722.0694444444445)]
# DIFFERENCES
# each_interval  [9.795454545454545, 10]
# new_unfit_interval   [[8.931818181818183, 9.136363636363637]]
# MAIN interval list from VAL: [[7.613636363636363, 7.954545454545455], [8.931818181818183, 9.136363636363637], [9.795454545454545, 10]]
# Validator...
# What are POINTS  [[3.0, 422.25], [3.3333333333333335, 435.15277777777794], [3.6666666666666665, 443.56944444444457], [5.0, 492.68055555555554], [5.333333333333333, 489.6527777777779], [5.666666666666667, 520.4722222222221], [7.0, 577.8333333333333], [7.2727272727272725, 575.9444444444443], [7.545454545454545, 574.8055555555557], [7.818181818181818, 635.1111111111112], [8.09090909090909, 635.0277777777777], [8.363636363636363, 604.8472222222223], [8.636363636363637, 659.9583333333333], [8.90909090909091, 661.4444444444441], [9.181818181818182, 699.5972222222224], [9.454545454545455, 716.6805555555554], [9.727272727272727, 717.1249999999998], [7.818181818181818, 635.1111111111112], [7.818181818181818, 635.1111111111112], [9, 699.5972222222224], (10, 722.0694444444445)]
#        *** USING local_exploration_validator_A
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# equation,
#  y =  5.819662722371758e-07x^9 + 4.549918128399738e-06x^8 + 3.557208718567068e-05x^7 + 0.0002781090452697889x^6 + 0.002174307081200168x^5 + 0.01699912808938313x^4 + 0.13290227415335903x^3 + 1.0390541433808071x^2 + 8.123514211886311x^1 + 63.51111111111116
# unfit_points
#  [(7.818181818181818, 635.1111111111112), (7.818181818181818, 635.1111111111112), (7.818181818181818, 635.1111111111112)]
# local_unfit_interval
# , [[7.613636363636363, 7.954545454545455]]
# This is UNFIT POINTS  [(9, 699.5972222222224)]
# This is UNFIT POINTS  [(10, 722.0694444444445)]
# DIFFERENCES
# each_interval  [9.795454545454545, 10]
# new_unfit_interval   []
# MAIN interval list from VAL: [[8.931818181818183, 9.136363636363637], [9.795454545454545, 10]]
# Print interval [8, 9]
# volume [3600, 3625, 3650, 3675]
# MOD list [[8.0, [3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600]], [8.333333333333334, [3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625]], [8.666666666666666, [3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650]]]
# Print interval [9, 10]
# volume [3700, 3725, 3750, 3775]
# MOD list [[8.0, [3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600]], [8.333333333333334, [3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625]], [8.666666666666666, [3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650]], [9.0, [3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700]], [9.333333333333334, [3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725]], [9.666666666666666, [3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750]]]
# MAIN mod outcome [[8.0, [3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600, 3600]], [8.333333333333334, [3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625, 3625]], [8.666666666666666, [3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650, 3650]], [9.0, [3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700, 3700]], [9.333333333333334, [3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725, 3725]], [9.666666666666666, [3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750, 3750]]]
# Simulator...
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Running sumo simulator
#  Retrying in 1 seconds
# Validator...
# What are POINTS  [[8.0, 635.0277777777777], [8.333333333333334, 604.8472222222223], [8.666666666666666, 659.9583333333333], [9.0, 699.5972222222224], [9.333333333333334, 716.6805555555554], [9.666666666666666, 717.1249999999998], (9, 699.5972222222224), (10, 722.0694444444445)]
#        *** USING local_exploration_validator_A
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# /home/amy/tmp/repos/SimEx/notebooks/validator.py:41: RankWarning: Polyfit may be poorly conditioned
#   current_coeff = np.polyfit(x_values, y_values, deg=degree)
# equation,
#  y =  1.8057827143525767e-07x^9 + 1.6252044429173184e-06x^8 + 1.462683998625587e-05x^7 + 0.00013164155987630284x^6 + 0.0011847740388867254x^5 + 0.010662966349980525x^4 + 0.09596669714982477x^3 + 0.8637002743484226x^2 + 7.773302469135806x^1 + 69.95972222222223
# unfit_points
#  [(9.0, 699.5972222222224), (9, 699.5972222222224)]
# local_unfit_interval
# , [[8.931818181818183, 9.136363636363637]]
# This is UNFIT POINTS  [(10, 722.0694444444445)]
# DIFFERENCES
# each_interval  [9.795454545454545, 10]
# new_unfit_interval   []
# MAIN modx [8.0, 8.333333333333334, 8.666666666666666, 9.0, 9.333333333333334, 9.666666666666666]
# Validator...
# What are POINTS  [[8.0, 635.0277777777777], [8.333333333333334, 604.8472222222223], [8.666666666666666, 659.9583333333333], [9.0, 699.5972222222224], [9.333333333333334, 716.6805555555554], [9.666666666666666, 717.1249999999998], (10, 722.0694444444445)]
# This is UNFIT POINTS  [(10, 722.0694444444445)]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[3], line 55
#      51     break
#      54 # Calls Validator controller
# ---> 55 intervals_list =  validator_controller_vsl.validate(mod_x_list=np.array(mod_x),sim_y_list=np.array(sim_y_list), selected_validator=components['validator'],global_interval=[1, 10])
#      56 print("MAIN interval list from VAL:", intervals_list)
#      57 # print(f"Fitted curve {validator_controller_vsl.fitted_curve} and Pred values {validator_controller_vsl.predicted_values}")
#      58
#      59 # Updates interval_list to new range output from validator controller
#      60 # No more unfit intervals -> write MAIN log
#
# File ~/tmp/repos/SimEx/notebooks/validator_controller.py:67, in ValidatorController.validate(self, mod_x_list, sim_y_list, selected_validator, global_interval)
#      64         validator_unfit_points.append(new_unfit_points)
#      65         print('equation,\n', equation, '\nunfit_points\n', unfit_points, '\nlocal_unfit_interval\n,',
#      66               fit_interval)
# ---> 67 print("DIFFERENCES \neach_interval ", each_interval, "\nnew_unfit_interval  ", new_unfit_interval)
#      69 validator_unfit_intervals = [item for sublist in validator_unfit_intervals for item in sublist]
#      70 validator_unfit_points = [item for sublist in validator_unfit_points for item in sublist]
#
# UnboundLocalError: local variable 'new_unfit_interval' referenced before assignment

# %% [markdown]
# ## Run without vsl

# %%
# IMPORT LIBRARIES
import numpy as np

from components_configuration import components
from global_settings import simexSettings,mds

from validator_controller import ValidatorController
from modifier_controller import ModifierController
from simulator_controller import SimulatorController
from logger_utils import Logger

validator_controller_novsl = ValidatorController()
logger = Logger()
logger_main_arguments = {}
is_main_func = True

# SUMO vsl
from controller_modifier_scenarios import Controller

modlist_novsl = Controller.get_list_of_modifiers(10)

mod_x_novsl,sim_y_list_novsl = SimulatorController.simulator(modlist_novsl,selected_simulator=components['sumo_simulator_novsl'])
assert len(mod_x_novsl) == len(sim_y_list_novsl)

while is_main_func:
    # SUMO vsl generate modifiers [[1,[2900,...2900],[2,[3000,...3000]....]
    # modlist = Controller.get_list_of_modifiers(10)
    # print(f"Mod list: {modlist}")
    # mod_x_list = modlist

    # Calls Simulator
    # Input: list of ids and modifiers [[1,[2900,...2900],[2,[3000,...3000]....]
    # Output: IDs,SIMULATED(values) [[1,388.88],[2,420.22]]
    # mod_x,sim_y_list = SimulatorController.simulator(modlist,selected_simulator=components['sumo_simulator_novsl'])
    # assert len(mod_x) == len(sim_y_list)

    print("MAIN modx", mod_x)

    # Calls Validator controller
    intervals_list_novsl =  validator_controller_novsl.validate(mod_x_list=np.array(mod_x),sim_y_list=np.array(sim_y_list), selected_validator=components['validator'],global_interval=[1, 10])
    print("MAIN interval list from VAL:", intervals_list_novsl)
    print(f"Fitted curve {validator_controller_novsl.fitted_curve} and Pred values {validator_controller_novsl.predicted_values}")
    
    # Updates interval_list to new range output from validator controller
    # No more unfit intervals -> write MAIN log
    if not intervals_list_novsl:
        is_main_func = False
        logger_main_arguments['log_contex'] = 'overall MAIN stats'
        logger_main_arguments['main_status'] = 'no unfit intervals'
        logger.log_main(logger_main_arguments)


# MAIN cycle completed/interrupted -> write OVERALL statistics        
logger_main_arguments['log_contex'] = 'Overall Stats'                          
logger_main_arguments['main_status'] = 'end cycle'
logger.log_main(logger_main_arguments)

# %%
import matplotlib.pyplot as plt
from global_settings import vfs

plt.figure(figsize=(10, 6))
# Plot for vsl
for controller in [validator_controller_vsl,validator_controller_novsl]:
# controller= validator_controller_novsl
    print(f"X values and Y values {controller.x_values}{controller.y_values} predicted values {controller.predicted_values}")
    plt.scatter(controller.x_values, controller.y_values, label=f'Original Data ')
    plt.scatter(controller.x_values, controller.predicted_values, label=f'Predicted y Data ', marker='x')
    plt.plot(controller.fitted_curve[2], controller.fitted_curve[1], color='red', label=f'Polynomial Regression')
    plt.plot(controller.fitted_curve[2], controller.fitted_curve[1] + vfs["threshold_y_fitting"], color='black', label=f'threshold ')
    plt.plot(controller.fitted_curve[2], controller.fitted_curve[1] - vfs["threshold_y_fitting"], color='black', label=f'threshold ')


plt.xlabel('X Values')
plt.ylabel('Y Values')
plt.title('Fitted Curve with unfit Intervals')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       4 plt.figure(figsize=(10, 6))
#       5 # Plot for vsl
# ----> 6 for controller in [validator_controller_vsl,validator_controller_novsl]:
#       7 # controller= validator_controller_novsl
#       8     print(f"X values and Y values {controller.x_values}{controller.y_values} predicted values {controller.predicted_values}")
#       9     plt.scatter(controller.x_values, controller.y_values, label=f'Original Data ')
#
# NameError: name 'validator_controller_novsl' is not defined
