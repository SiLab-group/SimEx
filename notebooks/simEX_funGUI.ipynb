# %%
#IMPORTS
from sklearn import preprocessing
## VALIDATOR FILE: :
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import HuberRegressor
from sklearn.preprocessing import StandardScaler
from global_settings import threshold_x_interval,threshold_y_fitting, mdv
from itertools import compress
import Validator
import Modifier
import Simulator

# %% [markdown]
# ## Part 3: VALIDATOR.py to test
# modifier and simulator working in dynamic way, with hardcoded ranges
# * next step, extract the ranges  DONE

# %%
validator = Validator
modifier = Modifier
simulator = Simulator
appendedvars=[]


### TEST CASE:
# Generate x values
mod_x = np.linspace(1,20,40)
# Generate y values
sim_y_list = mod_x*2

# Add two ranges of outliers
outliers_indices = [0,1,7,11,12,13,14,22,24,35,36]
outliers_values = np.array([3,0,32, -1,0.6,0,0,25,26,18,17.5])

sim_y_list[outliers_indices] = outliers_values
print('** Sim y and Mod x output\n', sim_y_list,'\n',mod_x,'\n') 


# Extracting x and y values for plotting
x_values = mod_x
y_values = sim_y_list

output = validator.Validator.validator_controller(mod_x_list=x_values,sim_y_list=y_values)
print('** Validator output\n', output,'\n\n')
# Out:
# ** Sim y and Mod x output
#  [ 3.          0.          3.94871795  4.92307692  5.8974359   6.87179487
#   7.84615385 32.          9.79487179 10.76923077 11.74358974 -1.
#   0.6         0.          0.         16.61538462 17.58974359 18.56410256
#  19.53846154 20.51282051 21.48717949 22.46153846 25.         24.41025641
#  26.         26.35897436 27.33333333 28.30769231 29.28205128 30.25641026
#  31.23076923 32.20512821 33.17948718 34.15384615 35.12820513 18.
#  17.5        38.05128205 39.02564103 40.        ]
#  [ 1.          1.48717949  1.97435897  2.46153846  2.94871795  3.43589744
#   3.92307692  4.41025641  4.8974359   5.38461538  5.87179487  6.35897436
#   6.84615385  7.33333333  7.82051282  8.30769231  8.79487179  9.28205128
#   9.76923077 10.25641026 10.74358974 11.23076923 11.71794872 12.20512821
#  12.69230769 13.17948718 13.66666667 14.15384615 14.64102564 15.12820513
#  15.61538462 16.1025641  16.58974359 17.07692308 17.56410256 18.05128205
#  18.53846154 19.02564103 19.51282051 20.        ]
#
#        *** USING validator_controller
#        *** USING local_exploration_validator_A
#        *** USING fit_curve
#        *** OUTPUT fit_curve slope, intercept [0.00000000e+00 1.82123063e+00 1.68913856e-04] 0.06779303117520641
#
#
#
#
# Residuals:  [  1.11  -2.78   0.29   0.37   0.46   0.54   0.63  23.9    0.8    0.89
#    0.97 -12.66 -11.94 -13.43 -14.32   1.41   1.49   1.57   1.66   1.75
#    1.84   1.92   3.57   2.09   2.79   2.26   2.34   2.43   2.51   2.6
#    2.68   2.77   2.85   2.93   3.02 -15.   -16.39   3.27   3.36   3.44]
# 5
# least_fit_indices [ 7 11 12 13 14 35 36]
# least_fit_points [[4.41, 32.0], [6.36, -1.0], [6.85, 0.6], [7.33, 0.0], [7.82, 0.0], [18.05, 18.0], [18.54, 17.5]]
#
#
#
#
# this is i: 0
# this is listofranges: []
#
# this is len(current_range)==0
#
# this is i: 1
# this is listofranges: []
#
# this is len(current_range)==0
#
# this is i: 2
# this is listofranges: []
#
# this is len(current_range)==0
#
# this is i: 3
# this is listofranges: []
#
# this is len(current_range)==0
#
# this is i: 4
# this is listofranges: []
#
# this is len(current_range)==0
#
# this is i: 5
# this is listofranges: []
#
# this is len(current_range)==0
#
# this is i: 6
# this is listofranges: []
#
# this is len(current_range)==0
#
# this is i: 7
# this is listofranges: []
#
#
# this is len(current_range)==0 and 0<i<len(x_values)
#
# this is i: 8
# this is listofranges: []
#
#
# this is len(current_range)==0 else
#
# this is i: 9
# this is listofranges: [[4.044871794871795, 4.7756410256410255]]
#
# this is len(current_range)==0
#
# this is i: 10
# this is listofranges: [[4.044871794871795, 4.7756410256410255]]
#
# this is len(current_range)==0
#
# this is i: 11
# this is listofranges: [[4.044871794871795, 4.7756410256410255]]
#
#
# this is len(current_range)==0 and 0<i<len(x_values)
#
# this is i: 12
# this is listofranges: [[4.044871794871795, 4.7756410256410255]]
#
#
# this is i: 13
# this is listofranges: [[4.044871794871795, 4.7756410256410255]]
#
#
# this is i: 14
# this is listofranges: [[4.044871794871795, 4.7756410256410255]]
#
#
# this is i: 15
# this is listofranges: [[4.044871794871795, 4.7756410256410255]]
#
#
# this is len(current_range)==0 else
#
# this is i: 16
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 17
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 18
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 19
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 20
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 21
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 22
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 23
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 24
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 25
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 26
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 27
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 28
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 29
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 30
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 31
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 32
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 33
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 34
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
# this is len(current_range)==0
#
# this is i: 35
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
#
# this is len(current_range)==0 and 0<i<len(x_values)
#
# this is i: 36
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
#
# this is i: 37
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434]]
#
#
# this is len(current_range)==0 else
#
# this is i: 38
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434], [17.685897435897434, 18.903846153846153]]
#
# this is len(current_range)==0
#
# this is i: 39
# this is listofranges: [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434], [17.685897435897434, 18.903846153846153]]
#
# this is len(current_range)==0
#
#
#
#  list of ranges:  [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434], [17.685897435897434, 18.903846153846153]]
#
#
#
#        *** USING plot_curve
#        *** OUTPUT unfitting_ranges [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434], [17.685897435897434, 18.903846153846153]]
#
#        *** OUTPUT validator_ranges [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434], [17.685897435897434, 18.903846153846153]]
#
# ** Validator output
#  [[4.044871794871795, 4.7756410256410255], [5.993589743589743, 8.185897435897434], [17.685897435897434, 18.903846153846153]]

# %% [markdown]
# ## PART 4: Main Func: with Modifier.py
# Error: the NaN values for X show up when Modifier can't generate (given the interval) new values.

# %%
# PLACEHOLDER FOR THE MAIN FUNCTION V2
#IMPORTS
from sklearn import preprocessing
## VALIDATOR FILE: :
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import HuberRegressor
from sklearn.preprocessing import StandardScaler
from global_settings import threshold_x_interval,threshold_y_fitting, mdv
from itertools import compress
import Validator
import Modifier
import Simulator

from global_settings import mdv
from Validator import Validator
from Modifier import Modifier
from Simulator import Simulator

print('* MDV: \n',mdv,'\n')

validator = Validator
modifier = Modifier
simulator = Simulator
appendedvars=[]

mainfunc=True
# Initialize interval list
interval_lists=[(mdv["domain_min_range"], mdv["domain_max_range"])]
x=1
while mainfunc==True:
    mod_x_list= modifier.modifier_controller(range_list=interval_lists,local_modifier=modifier.local_modifier_A, do_plot=False)

    if mod_x_list == False: # FALSE IF ["modifier_data_point"] < mdv["modifier_incremental_unit"]:
        print('*   ITERATIONS END HERE   *')
        break

    mod_x,sim_y_list = simulator.simulator_controller(mod_x_list,selected_function=simulator.sim_func_B)
    assert len(mod_x) == len(sim_y_list)
    
    print('\n\n Modx: ',mod_x,'\nsymx: ',sim_y_list)
    print('\nValidator ...')
    ranges = validator.validator_controller(mod_x_list=np.array(mod_x),sim_y_list=np.array(sim_y_list))
    interval_lists = ranges
    print('** Validator output\n', ranges,'\n\n')
# Out:
# * MDV:
#  {'domain_min_range': 1, 'domain_max_range': 100, 'modifier_incremental_unit': 3, 'modifier_data_point': 10}
#
#
# Modifier controller...
#   * Interval:  [(1, 100)]
#      * Iterations within Modifier:  0
#
# Simulator...
#   * Sim_y shape:    (10,)
#
#
#  Modx:  [1.0, 2.4347826086956523, 6.260869565217392, 12.478260869565217, 21.08695652173913, 32.086956521739125, 45.47826086956522, 61.26086956521739, 79.43478260869566, 100.0]
# symx:  [-7.673835104759321, -13.593556797117664, -12.113388701011118, 1.9056580744617921, -3.0091593931400364, 9.316601856756847, 22.950442117892933, 38.31481943462631, 32.62024590171626, 67.58769230989591]
#
# Validator ...
#        *** USING validator_controller
#        *** USING local_exploration_validator_A
#        *** USING fit_curve
#        *** OUTPUT fit_curve slope, intercept [0.         0.63755142 0.00110017] -12.037515646451626
#
#
#
#
# Residuals:  [  3.73  -3.11  -4.11   5.82  -4.91  -0.23   3.72   7.16 -12.93   4.87]
# 5
# least_fit_indices [3 7 8]
# least_fit_points [[12.48, 1.91], [61.26, 38.31], [79.43, 32.62]]
#
#
#
#
# this is i: 0
# this is listofranges: []
#
# this is len(current_range)==0
#
# this is i: 1
# this is listofranges: []
#
# this is len(current_range)==0
#
# this is i: 2
# this is listofranges: []
#
# this is len(current_range)==0
#
# this is i: 3
# this is listofranges: []
#
#
# this is len(current_range)==0 and 0<i<len(x_values)
#
# this is i: 4
# this is listofranges: []
#
#
# this is len(current_range)==0 else
#
# this is i: 5
# this is listofranges: [[7.815217391304348, 18.93478260869565]]
#
# this is len(current_range)==0
#
# this is i: 6
# this is listofranges: [[7.815217391304348, 18.93478260869565]]
#
# this is len(current_range)==0
#
# this is i: 7
# this is listofranges: [[7.815217391304348, 18.93478260869565]]
#
#
# this is len(current_range)==0 and 0<i<len(x_values)
#
# this is i: 8
# this is listofranges: [[7.815217391304348, 18.93478260869565]]
#
#
# this is i: 9
# this is listofranges: [[7.815217391304348, 18.93478260869565]]
#
#
# this is len(current_range)==0 else
#
#
#
#  list of ranges:  [[7.815217391304348, 18.93478260869565], [49.423913043478265, 94.8586956521739]]
#
#
#
#        *** USING plot_curve
#        *** OUTPUT unfitting_ranges [[7.815217391304348, 18.93478260869565], [49.423913043478265, 94.8586956521739]]
#
#        *** OUTPUT validator_ranges [[7.815217391304348, 18.93478260869565], [49.423913043478265, 94.8586956521739]]
#
# ** Validator output
#  [[7.815217391304348, 18.93478260869565], [49.423913043478265, 94.8586956521739]]
#
#
#
# Modifier controller...
#   * Interval:  [[7.815217391304348, 18.93478260869565], [49.423913043478265, 94.8586956521739]]
#      * Iterations within Modifier:  0
#      * Iterations within Modifier:  1
#
# Simulator...
#   * Sim_y shape:    (9,)
#
#
#  Modx:  [7.815217391304348, 18.93478260869565, 49.423913043478265, 55.11465638148668, 61.55808789153811, 68.75420757363254, 76.70301542777, 85.40451145395045, 94.8586956521739]
# symx:  [-5.096313330420757, 16.949536211490482, 3.836117792206455, 13.811780076181154, 34.7608406469969, 41.515534597352364, 40.15451134956347, 44.95944718591671, 43.81108992224807]
#
# Validator ...
#        *** USING validator_controller
#        *** USING local_exploration_validator_A
#        *** USING fit_curve
#        *** OUTPUT fit_curve slope, intercept [0.         0.33477392 0.00227489] -2.460317348434934
#
#
#
#
# Residuals:  [ -5.39  12.26 -15.8   -9.09   7.99  10.21   3.55   2.24  -5.96]
# 5
# least_fit_indices [0 1 2 3 4 5 8]
# least_fit_points [[7.82, -5.1], [18.93, 16.95], [49.42, 3.84], [55.11, 13.81], [61.56, 34.76], [68.75, 41.52], [94.86, 43.81]]
#
#
#
#
# this is i: 0
# this is listofranges: []
#
#
# this is len(current_range)==0 and i==0
#
# this is i: 1
# this is listofranges: []
#
#
# this is i: 2
# this is listofranges: []
#
#
# this is i: 3
# this is listofranges: []
#
#
# this is i: 4
# this is listofranges: []
#
#
# this is i: 5
# this is listofranges: []
#
#
# this is i: 6
# this is listofranges: []
#
#
# this is len(current_range)==0 else
#
# this is i: 7
# this is listofranges: [[7.815217391304348, 74.71581346423564]]
#
# this is len(current_range)==0
#
# this is i: 8
# this is listofranges: [[7.815217391304348, 74.71581346423564]]
#
#
# this is len(current_range)==0 and i==len(x_values)
#
#
#
#  list of ranges:  [[7.815217391304348, 74.71581346423564], [87.76805750350631, 94.8586956521739]]
#
#
#
#        *** USING plot_curve
#        *** OUTPUT unfitting_ranges [[7.815217391304348, 74.71581346423564], [87.76805750350631, 94.8586956521739]]
#
#        *** OUTPUT validator_ranges [[7.815217391304348, 74.71581346423564], [87.76805750350631, 94.8586956521739]]
#
# ** Validator output
#  [[7.815217391304348, 74.71581346423564], [87.76805750350631, 94.8586956521739]]
#
#
#
# Modifier controller...
#   * Interval:  [[7.815217391304348, 74.71581346423564], [87.76805750350631, 94.8586956521739]]
#      * Iterations within Modifier:  0
#      * Iterations within Modifier:  1
#
# Simulator...
#   * Sim_y shape:    (19,)
#
#
#  Modx:  [7.815217391304348, 8.845985174778566, 10.296822221063982, 12.167728530160597, 14.45870410206841, 17.16974893678742, 20.30086303431763, 23.852046394659038, 27.823299017811646, 32.214620903775455, 37.026012052550456, 42.257472464136654, 47.90900213853406, 53.980601075742655, 60.47226927576246, 67.38400673859344, 74.71581346423564, 87.76805750350631, 94.8586956521739]
# symx:  [13.99426648154812, 8.586093133014817, 12.353747974458475, -8.394087039389253, 5.266361181643778, -11.420863678848661, 7.9397187443963375, 12.371343941074105, 21.924228695443603, 15.415491556390162, 20.07788457494184, 18.88735687128912, 32.204490766350844, 11.473083679400823, 26.961334902541275, 37.43966370066544, 46.380472655306164, 60.52308139916476, 32.32761125408937]
#
# Validator ...
#        *** USING validator_controller
#        *** USING local_exploration_validator_A
#        *** USING fit_curve
#        *** OUTPUT fit_curve slope, intercept [0.00000000e+00 5.23075229e-01 1.46740934e-05] -1.2672346390081834
#
#
#
#
# Residuals:  [ 11.17   5.23   8.23 -13.49  -1.03 -19.14  -1.42   1.15   8.62  -0.18
#    1.96  -1.97   8.37 -15.54  -3.46   3.39   8.48  15.76 -16.15]
# 5
# least_fit_indices [ 0  1  2  3  5  8 12 13 16 17 18]
# least_fit_points [[7.82, 13.99], [8.85, 8.59], [10.3, 12.35], [12.17, -8.39], [17.17, -11.42], [27.82, 21.92], [47.91, 32.2], [53.98, 11.47], [74.72, 46.38], [87.77, 60.52], [94.86, 32.33]]
#
#
#
#
# this is i: 0
# this is listofranges: []
#
#
# this is len(current_range)==0 and i==0
#
# this is i: 1
# this is listofranges: []
#
#
# this is i: 2
# this is listofranges: []
#
#
# this is i: 3
# this is listofranges: []
#
#
# this is i: 4
# this is listofranges: []
#
#
# this is len(current_range)==0 else
#
# this is i: 5
# this is listofranges: [[7.815217391304348, 13.885960209091456]]
#
#
# this is len(current_range)==0 and 0<i<len(x_values)
#
# this is i: 6
# this is listofranges: [[7.815217391304348, 13.885960209091456]]
#
#
# this is len(current_range)==0 else
#
# this is i: 7
# this is listofranges: [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508]]
#
# this is len(current_range)==0
#
# this is i: 8
# this is listofranges: [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508]]
#
#
# this is len(current_range)==0 and 0<i<len(x_values)
#
# this is i: 9
# this is listofranges: [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508]]
#
#
# this is len(current_range)==0 else
#
# this is i: 10
# this is listofranges: [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508], [24.84485955044719, 31.116790432284503]]
#
# this is len(current_range)==0
#
# this is i: 11
# this is listofranges: [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508], [24.84485955044719, 31.116790432284503]]
#
# this is len(current_range)==0
#
# this is i: 12
# this is listofranges: [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508], [24.84485955044719, 31.116790432284503]]
#
#
# this is len(current_range)==0 and 0<i<len(x_values)
#
# this is i: 13
# this is listofranges: [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508], [24.84485955044719, 31.116790432284503]]
#
#
# this is i: 14
# this is listofranges: [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508], [24.84485955044719, 31.116790432284503]]
#
#
# this is len(current_range)==0 else
#
# this is i: 15
# this is listofranges: [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508], [24.84485955044719, 31.116790432284503], [43.67035488273601, 58.84935222575751]]
#
# this is len(current_range)==0
#
# this is i: 16
# this is listofranges: [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508], [24.84485955044719, 31.116790432284503], [43.67035488273601, 58.84935222575751]]
#
#
# this is len(current_range)==0 and 0<i<len(x_values)
#
# this is i: 17
# this is listofranges: [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508], [24.84485955044719, 31.116790432284503], [43.67035488273601, 58.84935222575751]]
#
#
# this is i: 18
# this is listofranges: [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508], [24.84485955044719, 31.116790432284503], [43.67035488273601, 58.84935222575751]]
#
#
# this is len(current_range)>0 and i==len(x_values)
#
#
#
#  list of ranges:  [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508], [24.84485955044719, 31.116790432284503], [43.67035488273601, 58.84935222575751], [69.21695842000399, 94.8586956521739]]
#
#
#
#        *** USING plot_curve
#        *** OUTPUT unfitting_ranges [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508], [24.84485955044719, 31.116790432284503], [43.67035488273601, 58.84935222575751], [69.21695842000399, 94.8586956521739]]
#
#        *** OUTPUT validator_ranges [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508], [24.84485955044719, 31.116790432284503], [43.67035488273601, 58.84935222575751], [69.21695842000399, 94.8586956521739]]
#
# ** Validator output
#  [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508], [24.84485955044719, 31.116790432284503], [43.67035488273601, 58.84935222575751], [69.21695842000399, 94.8586956521739]]
#
#
#
# Modifier controller...
#   * Interval:  [[7.815217391304348, 13.885960209091456], [15.136465310748163, 19.51808450993508], [24.84485955044719, 31.116790432284503], [43.67035488273601, 58.84935222575751], [69.21695842000399, 94.8586956521739]]
# *   ITERATIONS END HERE   *
